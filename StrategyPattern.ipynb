# %% [markdown]
# <a href="https://colab.research.google.com/github/mattderri/CMP/blob/main/StrategyPattern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
analytical="/content/drive/My Drive/Colab Notebooks/CMP/Analytical_results.csv"
rungekutta="/content/drive/My Drive/Colab Notebooks/CMP/RungeKutta_results.csv"

# %%
analytical_data = pd.read_csv(analytical,sep='\t')
rungekutta_data = pd.read_csv(rungekutta,sep='\t')
t = analytical_data['t'].values
print(analytical_data.shape)
print(rungekutta_data.shape)

# %%
print(rk.shape)
t=rk['t'].values
# Out:
# (10000, 7)
# array([0.000e+00, 1.000e-02, 2.000e-02, ..., 9.997e+01, 9.998e+01,
#        9.999e+01])

# %%
plt.figure(figsize=(14,8))
#plt.ylim(-40,140)
plt.grid()

plt.plot(t,analytical_data['v_x'].values,'-',color='blue',label='Analytical')
plt.plot(t,rungekutta_data['v_x'].values,'-',color='red',label='Runge Kutta')

plt.xlabel("Tempo [s]",fontsize=18)
plt.ylabel(r'$v_x [m]$',fontsize=18)
plt.legend(loc=1, prop={'size': 16})

# %%
plt.figure(figsize=(14,8))
#plt.ylim(-40,140)
plt.grid()

plt.plot(t,analytical_data['v_y'].values,'-',color='blue',label='Analytical')
plt.plot(t,rungekutta_data['v_y'].values,'-',color='red',label='Runge Kutta')


#x = np.linspace(0, 140, 1000)
#plt.plot(x, x,color='red')

#my_xticks=['0','50','100','150']
#my_yticks=['0','50','100']
#plt.xticks([0,50,100,150],my_xticks,fontsize=14)
#plt.yticks([0,50,100],my_yticks,fontsize=14)

plt.xlabel("Tempo [s]",fontsize=18)
plt.ylabel(r'$v_y [m/s]$',fontsize=18)
plt.legend(loc=1, prop={'size': 16})
